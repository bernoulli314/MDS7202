# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # **Proyecto 1 - MDS7202 Laboratorio de Programación Científica para Ciencia de Datos 📚**
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# *Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir.*
#
# ### Equipo:
#
# - \<Joaquín Cisternas\>
# - \<Diego González\>
#
#
# ### Link de repositorio de GitHub: `\<https://github.com/jcist/MDS7202\>`
#
# Fecha límite de entrega 📆: 27 de Octubre de 2023.

# %% [markdown]
# ----
#
# ## Reglas
#
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://worldskateamerica.org/wp-content/uploads/2023/07/SANTIAGO-2023-1-768x153.jpg" alt="Descripción de la imagen">
# </div>
#
# En un Chile azotado por un profundo caos político-económico y el resurgimiento de programas de televisión de dudosa calidad, todas las miradas y esperanzas son depositadas en el éxito de un único evento: Santiago 2023. La nación necesitaba desesperadamente un respiro, y los Juegos de Santiago 2023 prometían ser una luz al final del túnel.
#
# El Presidente de la República -conocido en las calles como Bombín-, consciente de la importancia de este evento para la revitalización del país, decide convocar a usted y su equipo en calidad de expertos en análisis de datos y estadísticas. Con gran solemnidad, el presidente les encomienda una importante y peligrosa: liderar un proyecto que permitiera caracterizar de forma automática y eficiente los datos generados por estos magnos juegos. Para esto, el presidente le destaca que la solución debe considerar los siguientes puntos:
# - Caracterización automática de los datos
# - La solución debe ser compatible con cualquier dataset
# - Se les facilita el dataset *olimpiadas.parquet*, el cual recopila data de diferentes juegos olímpicos realizados en los últimos años

# %% [markdown]
# ## 1.1 Creación de `Profiler` Class (4.0 puntos)
#
# Cree la clase `Profiler`. Como mínimo, esta debe tener las siguientes funcionalidades:
#
# 1. El método constructor, el cual debe recibir los datos a procesar en formato `Pandas DataFrame`. Además, este método debe generar una carpeta en su directorio de trabajo con el nombre `EDA_fecha`, donde `fecha` corresponda a la fecha de ejecución en formato `DD-MM-YYYY`.
#
# 2. El método `summarize`, el cual debe caracterizar las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Reportar el tipo de variable
#     - Reportar el número y/o porcentaje de valores únicos de la variable
#     - Reportar el número y/o porcentaje de valores nulos
#     - Si la variables es numérica:
#         - Reportar el número y/o porcentaje de valores cero, negativos y outliers
#         - Reportar estadística descriptiva como el valor mínimo, máximo, promedio y los percentiles 25, 50, 75 y 100
#    - Levantar una alerta en caso de encontrar alguna anomalía fuera de lo común (el criterio debe ser ajustable por el usuario)
#    - Guardar sus resultados en el directorio `EDA_fecha/summary.txt`. El archivo debe separar de forma clara y ordenada los resultados de cada punto.
#
# 3. El método `plot_vars`, el cual debe graficar la distribución e interraciones de las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/plots`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Para las variables numéricas:
#         - Genere un gráfico de distribución de densidad
#         - Grafique la correlación entre las variables
#     - Para las variables categóricas:
#         - Genere un histograma de las top N categorías (N debe ser un parámetro ajustable)
#         - Grafique el coeficiente V de Cramer entre las variables
#     - Guardar cada gráfico generado en la carpeta `EDA_fecha/plots` en formato `.pdf` y bajo el naming `variable.pdf`, donde `variable` es el nombre de la variable de interés
#
# 4. El método `clean_data`, el cual debe limpiar los datos para que luego puedan ser procesados. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clean_data`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Drop de valores duplicados
#     - Implementar como mínimo 2 técnicas para tratar los valores nulos, como:
#         - Drop de valores nulos
#         - Imputar valores nulos con alguna técnica de imputación
#         - Funcionalidad para escoger entre una técnica y la otra.
#     - Una de las columnas del dataframe presenta datos *no atómicos*. Separe dicha columna en las columnas que la compongan.
#         - Hint: ¿Qué caracteres permiten separar una columna de otra?
#         - Para las pruebas con el dataset nuevo, puede esperar que exista al menos una columna con este tipo de problema. Asuma que los separadores serán los mismos, aunque el número de columnas a separar puede ser distinto.
#     - Deberían usar `FunctionTransformer`.
#     - Guardar los datos procesados en formato `.csv` en el path `EDA_fecha/clean_data/data.csv`
#
# 5. El método `scale`, el cual debe preparar adecuadamente los datos para luego ser consumidos por algún tipo de algoritmo. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/scale`
#     - Procesar de forma adecuada los datos numéricos y categóricos:
#         - Su método debe recibir las técnicas de escalamiento como argumento de entrada (utilizar solo técnicas compatibles con el framework de `sklearn`)
#         - Para los atributos numéricos, se transforme los datos con un escalador logarítmico y un `MinMaxScaler`
#         - Asuma que no existen datos ordinales en su dataset
#     - Guardar todo este procesamiento en un `ColumnTransformer`.
#     - Guardar los datos limpios y transformados en formato `.csv` en el path `EDA_fecha/process/scaled_features.csv`
#
# 6. El método `make_clusters`, el cual debe generar clusters de los datos usando algún algoritmo de clusterización. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clusters`
#     - Generar un estudio del codo donde señale la cantidad de clusters optimos para el desarrollo.
#     - Su método debe recibir el algoritmo de clustering como argumento de entrada (utilizar solo algoritmos compatibles con el framework de `sklearn`).
#     - No olvide pre procesar adecuadamente los datos antes de implementar la técnica de clustering.
#     - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#     - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#     - Una vez generado los clusters, proyecte los datos a 2 dimensiones usando su técnica de reducción de dimensionalidad favorita y grafique los resultados coloreando por cluster.
#     - Guardar los datos con su respectivo cluster en formato `.csv` en el path `EDA_fecha/clusters/data_clusters.csv`. Guarde también los gráficos generados en el mismo path.
#
# 7. El método `detect_anomalies`, el cual debe detectar anomalías en los datos. Como mínimo, se espera que su método pueda:
#
#     - Crear la carpeta `EDA_fecha/anomalies`
#     - Implementar alguna técnica de detección de anomalías.
#     - Al igual que el punto anterior, su método debe considerar los siguientes puntos:
#         - No olvide pre procesar de forma adecuada los datos antes de implementar la técnica de detección de anomalía.
#         - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#         - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#         - Su método debe recibir el algoritmo como argumento de entrada
#         - Una vez generado las etiquetas, proyecte los datos a 2 dimensiones y grafique los resultados coloreando por las etiquetas predichas por el detector de anomalías
#     - Guardar los datos con su respectiva etiqueta en formato `.csv` en el path `EDA_fecha/anomalies/data_anomalies.csv`. Guarde también los gráficos generados en el mismo path.
#
# 8. El método `profile`, el cual debe ejecutar todos los métodos anteriores.
#
# 9. Crear el método `clearGarbage` para eliminar las carpetas/archivos creados/as por la clase `Profiler`.
#
# Algunas consideraciones generales:
# - Su clase será testeada con datos tabulares diferentes a los provistos. No desarrollen código *hardcodeado*: su clase debe ser capaz de funcionar para **cualquier** dataset.
# - Aplique todo su conocimiento sobre buenas prácticas de programación: se evaluará que su código sea limpio y ordenado.
# - Recuerden documentar cada una de las funcionalidades que implementen.
# - Recuerden adjuntar sus `requirements.txt` junto a su entrega de proyecto. **El código que no se pueda ejecutar por imcompatibilidades de librerías no será corregido.**

# %%
import os
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import shutil
from sklearn.ensemble import IsolationForest

# %%
class Profiler:
    def __init__(self, data):
        if not isinstance(data, pd.DataFrame):
            raise ValueError("Se espera un objeto de tipo pandas DataFrame como entrada")

        now = datetime.datetime.now()
        folder_name = 'EDA_' + now.strftime("%d-%m-%Y")
        if not os.path.exists(folder_name):
            os.mkdir(folder_name)
            os.mkdir(os.path.join(folder_name, "clean_data"))
        
        plots_folder = os.path.join(folder_name, 'plots')
        if not os.path.exists(plots_folder):
            os.mkdir(plots_folder)

        self.data = data
        self.output_folder = folder_name

    def get_data(self):
        return self.data

    def get_output_folder(self):
        return self.output_folder

    def summarize(self, columns_of_interest=None, threshold_outliers=3):
        if columns_of_interest is None:
            columns_of_interest = self.data.columns

        summary_file = os.path.join(self.output_folder, 'summary.txt')

        with open(summary_file, 'w') as f:
            f.write("Resumen del Dataset:\n")

            for column in columns_of_interest:
                if column in self.data.columns:
                    f.write(f"Variable: {column}\n")
                    data_column = self.data[column]

                    # Reportar el tipo de variable
                    f.write(f"Tipo de Variable: {data_column.dtype}\n")

                    # Reportar el número y porcentaje de valores únicos
                    unique_count = data_column.nunique()
                    total_count = len(data_column)
                    unique_percent = (unique_count / total_count) * 100
                    f.write(f"Número de Valores Únicos: {unique_count} ({unique_percent:.2f}%)\n")

                    # Reportar el número y porcentaje de valores nulos
                    null_count = data_column.isnull().sum()
                    null_percent = (null_count / total_count) * 100
                    f.write(f"Número de Valores Nulos: {null_count} ({null_percent:.2f}%)\n")

                    # Si la variable es numérica
                    if pd.api.types.is_numeric_dtype(data_column):
                        f.write("Estadísticas Descriptivas:\n")
                        f.write(f"Valor Mínimo: {data_column.min()}\n")
                        f.write(f"Percentil 25: {data_column.quantile(0.25)}\n")
                        f.write(f"Media: {data_column.mean()}\n")
                        f.write(f"Percentil 50 (Mediana): {data_column.median()}\n")
                        f.write(f"Percentil 75: {data_column.quantile(0.75)}\n")
                        f.write(f"Valor Máximo: {data_column.max()}\n")

                        # Reportar el número y porcentaje de valores cero
                        zero_count = (data_column == 0).sum()
                        zero_percent = (zero_count / total_count) * 100
                        f.write(f"Número de Valores Cero: {zero_count} ({zero_percent:.2f}%)\n")

                        # Reportar el número y porcentaje de valores negativos
                        negative_count = (data_column < 0).sum()
                        negative_percent = (negative_count / total_count) * 100
                        f.write(f"Número de Valores Negativos: {negative_count} ({negative_percent:.2f}%)\n")

                        # Reportar el número y porcentaje de valores atípicos (outliers)
                        iqr = data_column.quantile(0.75) - data_column.quantile(0.25)
                        lower_bound = data_column.quantile(0.25) - threshold_outliers * iqr
                        upper_bound = data_column.quantile(0.75) + threshold_outliers * iqr
                        outliers_count = ((data_column < lower_bound) | (data_column > upper_bound)).sum()
                        outliers_percent = (outliers_count / total_count) * 100
                        f.write(f"Número de Outliers: {outliers_count} ({outliers_percent:.2f}%)\n")

                    f.write("\n")
                else:
                    f.write(f"Variable '{column}' no encontrada en el DataFrame.\n\n")
            
        with open(summary_file, 'r') as texto:
            read_file = texto.read()
        
        print(read_file)
    
    def plot_vars(self, columns_of_interest=None, top_n_categories=10):
        if columns_of_interest is None:
            columns_of_interest = self.data.columns

        plots_folder = os.path.join(self.output_folder, 'plots')

        for column in columns_of_interest:
            if column in self.data.columns:
                data_column = self.data[column]
                plt.figure(figsize=(10, 8))

                if pd.api.types.is_numeric_dtype(data_column):
                    # Genere un gráfico de distribución de densidad para variables numéricas
                    sns.histplot(data_column, kde=True, color='b')
                    plt.title(f'Distribución de Densidad de {column}')
                    plt.xlabel(column)
                    plt.ylabel('Densidad')
                    plt.show()
                    file_path = os.path.join(plots_folder, f'{column}.pdf').replace("\\", "/")
                    plt.savefig(file_path)
                    plt.close()

                    # Grafique la correlación entre las variables numéricas
                    if len(columns_of_interest) > 1:
                        for col2 in columns_of_interest:
                            if col2 != column and pd.api.types.is_numeric_dtype(self.data[col2]):
                                sns.scatterplot(x=column, y=col2, data=self.data, alpha=.2)
                                plt.title(f'Correlación entre {column} y {col2}')
                                plt.xlabel(column)
                                plt.ylabel(col2)
                                plt.show()
                                file_path = os.path.join(plots_folder, f'{column}_vs_{col2}.pdf').replace("\\", "/")
                                plt.savefig(file_path)
                                plt.close()
                elif (isinstance(data_column.dtype, pd.CategoricalDtype) or not pd.api.types.is_numeric_dtype(data_column)):
                    # Genere un histograma de las top N categorías
                    top_categories = data_column.value_counts()[:top_n_categories]
                    sns.barplot(x=top_categories.index, y=top_categories.values)
                    plt.title(f'Histograma de las Top {top_n_categories} Categorías de {column}')
                    plt.xlabel(column)
                    plt.ylabel('Frecuencia')
                    plt.xticks(rotation=45)
                    plt.show()
                    file_path = os.path.join(plots_folder, f'{column}.pdf').replace("\\", "/")
                    plt.savefig(file_path)
                    plt.close()

                    # Grafique el coeficiente V de Cramer entre las variables categóricas
                    if len(columns_of_interest) > 1:
                        for col2 in columns_of_interest:
                            if col2 != column and (isinstance(self.data[col2].dtype, pd.CategoricalDtype) or not pd.api.types.is_numeric_dtype(self.data[col2])):
                                confusion_matrix = pd.crosstab(data_column, self.data[col2])
                                chi2, _, _, _ = chi2_contingency(confusion_matrix)
                                n = self.data.shape[0]
                                v_cramer = np.sqrt(chi2 / (n * (min(confusion_matrix.shape) - 1)))
                                sns.heatmap(np.array([[v_cramer]]), annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
                                plt.title(f'Coeficiente V de Cramer entre {column} y {col2}')
                                plt.show()
                                file_path = os.path.join(plots_folder, f'{column}_vs_{col2}_cramer.pdf').replace("\\", "/")
                                plt.savefig(file_path)
                                plt.close()

    def clean_data(self, columns_of_interest=None, drop_duplicates=True, impute_technique=None, separator=None):
        
        if columns_of_interest is None:
            columns_of_interest = self.data.columns

        for column in columns_of_interest:
            if column not in self.data.columns:
                raise ValueError(f"Columna '{column}' no encontrada en el DataFrame")

        clean_data_folder = os.path.join(self.output_folder, 'clean_data')
        if not os.path.exists(clean_data_folder):
            os.mkdir(clean_data_folder)

        # Crear una copia del DataFrame para el procesamiento
        cleaned_data = self.data.copy()
        c_data_interest = cleaned_data[columns_of_interest].copy()

        dropped_columns = []
        added_columns = []

        if separator != None:
            # Separar columnas no atómicas
            for column in columns_of_interest:
                if not pd.api.types.is_numeric_dtype(c_data_interest[column]):
                    c_data_interest[column] = c_data_interest[column].astype(str).replace(str(separator), ':', regex=True)
                    if c_data_interest[column].astype(str).str.contains(':').any():
                        new_columns = c_data_interest[column].str.split(':', expand=True)
                        new_columns.columns = [f"{column}_{i}" for i in range(new_columns.shape[1])]
                        added_columns.extend(new_columns)
                        c_data_interest = pd.concat([c_data_interest, new_columns], axis=1)
                        c_data_interest.drop(column, axis=1, inplace=True)
                        dropped_columns.append(column)
            columns_of_interest = c_data_interest.columns
            print(columns_of_interest)
        else:
            dropped_columns = columns_of_interest
            print("No se especificó un separador. No se realizará la separación de columnas.")

        
        # cambiar nan strings a nan de pandas
        tipos_nan = ['nan', 'NaN', 'NAN', 'Nan']
        for tipo in tipos_nan:
            c_data_interest.replace(tipo, np.nan, inplace=True)

        # Tratar valores nulos
        if impute_technique == 'drop':
            c_data_interest.dropna(subset=columns_of_interest, inplace=True)
        elif impute_technique == 'impute_mean':
            for column in columns_of_interest:
                c_data_interest[column] = pd.to_numeric(c_data_interest[column], errors='coerce')
                c_data_interest[column].fillna(c_data_interest[column].mean(), inplace=True)
        elif impute_technique == 'impute_zeros':
            for column in columns_of_interest:
                c_data_interest[column] = pd.to_numeric(c_data_interest[column], errors='coerce')
                c_data_interest[column].fillna(0, inplace=True)
        
        # quitar las columnas droppeadas del dataframe original
        if len(dropped_columns) > 0:
            cleaned_data.drop(dropped_columns, axis=1, inplace=True)

        if len(cleaned_data.columns) > 0:
            # agregar las columnas nuevas al dataframe original
            cleaned_data = pd.concat([cleaned_data, c_data_interest], axis=1)
        if len(cleaned_data.columns) == 0:
            cleaned_data = c_data_interest

        # Drop de valores duplicados
        if drop_duplicates:
            duplicated_data = cleaned_data.duplicated().sum()
            cleaned_data.drop_duplicates(inplace=True)
            print('Hay ', duplicated_data, ' datos duplicados')

        # Guardar los datos procesados en formato .csv
        cleaned_data_path = os.path.join(clean_data_folder, 'data.csv')
        cleaned_data.to_csv(cleaned_data_path, index=False)

        self.data = cleaned_data
        
    
    def scale(self, scalers=None):

        scale_folder = os.path.join(self.output_folder, 'scale')
        if not os.path.exists(scale_folder):
            os.mkdir(scale_folder)

        data_to_scale = self.data.copy()
        
        if 'anomalies' in data_to_scale.columns:
            data_to_scale.drop('anomalies', axis=1, inplace=True)

        # Obtener los nombres de las columnas numéricas y categóricas
        columnas_numericas = data_to_scale.select_dtypes(include=['number']).columns.tolist()
        columnas_categoricas = data_to_scale.select_dtypes(exclude=['number']).columns.tolist()


        # pipeline numerica
        num_pipe = Pipeline(
            steps=[
                ("log_scaler", FunctionTransformer(func=np.log1p, validate=False)),
                ("minmax_scaler", MinMaxScaler())
            ]
        )

        #pipeline categorica
        cat_steps = []

        if scalers:
            for name, scaler in scalers:
                cat_steps.append((name, scaler))
        
        if cat_steps:
            cat_pipe = Pipeline(cat_steps)
        else:
            cat_pipe = "passthrough"

        # column transformer
        prep = ColumnTransformer(
            transformers=[
                ('num', num_pipe, columnas_numericas),
                ('cat', cat_pipe, columnas_categoricas)
            ]
        )

        data_transformed = prep.fit_transform(data_to_scale)
        data_transformed_df = pd.DataFrame(data_transformed, columns=columnas_numericas + columnas_categoricas)

        # Guardar los datos procesados en formato .csv
        scaled_path = os.path.join(scale_folder, 'scaled_features.csv')
        data_transformed_df.to_csv(scaled_path, index=False)
        data_transformed_df[columnas_numericas] = data_transformed_df[columnas_numericas].astype(float)


        return(data_transformed_df)

    def make_clusters(self, algorithm = 'KMeans',separator=[','], scalers=None, min_clusters=1, max_clusters=10):
        
        if algorithm != 'KMeans':
            raise ValueError("Algoritmo de clustering no válido")
        
        cluster_folder = os.path.join(self.output_folder, 'cluster')
        if not os.path.exists(cluster_folder):
            os.mkdir(cluster_folder)

        # preprocesamiento de datos
        self.clean_data(separator = separator)
        scaled_data = self.scale(scalers=scalers)

        print("Procesamiento de datos completado.")

        # seleccion de columnas numericas
        numeric_columns = scaled_data.select_dtypes(include=['number']).columns

        # Realizar un estudio del codo para determinar el número óptimo de clusters
        inertia = []
        max_clusters = np.min([max_clusters, len(scaled_data)])
        for i in range(min_clusters, max_clusters):
            kmeans = KMeans(n_clusters=i, random_state=0)
            kmeans.fit(scaled_data[numeric_columns])
            inertia.append(kmeans.inertia_)

        # Encuentra el "codo" en la curva de la inercia
        diff = np.diff(inertia)
        diff_r = diff[1:] / diff[:-1]
        n_clusters = np.where(diff_r < 0.5)[0][0] + 2  # Escoge el primer punto donde la relación sea menor que 0.5

        # Graficar el codo
        plt.figure(figsize=(8, 6))
        plt.plot(range(min_clusters, max_clusters), inertia, marker='o', linestyle='--')
        plt.xlabel('Número de Clústeres')
        plt.ylabel('Inercia')
        plt.title('Método del Codo')
        plt.savefig(os.path.join(cluster_folder, 'elbow_plot.png'))
        plt.show()
        plt.close()

        print(f"El número óptimo de clústeres es: {n_clusters}")

        # pipeline 
        pipeline = Pipeline([
            ('kmeans', KMeans(n_clusters=n_clusters)),  # Aplicar K-Means con n_clusters
            ('pca', PCA(n_components=2))  # Reducir la dimensionalidad a 2 componentes principales
        ])

        pipeline.fit(scaled_data[numeric_columns])
        # Obtener las etiquetas de clúster de K-Means
        kmeans_labels = pipeline.named_steps['kmeans'].labels_

        # Ajustar el pipeline a los datos
        data_pca = pipeline.fit_transform(scaled_data[numeric_columns])

        # Graficar los datos con colores basados en las etiquetas de clúster
        plt.scatter(data_pca[:, 0], data_pca[:, 1], c=kmeans_labels, cmap='viridis')
        plt.title('Data PCA con Colores de K-Means Labels')
        plt.xlabel('Dimension 1')
        plt.ylabel('Dimension 2')
        plt.colorbar(label='Etiquetas de Clúster K-Means')
        plt.savefig(os.path.join(cluster_folder, 'cluster_projection.png'))
        plt.show()
        plt.close()

        self.data['cluster'] = kmeans_labels

        # Guardar los datos con su respectivo cluster en formato .csv
        cluster_data_path = os.path.join(cluster_folder, 'data_clusters.csv')
        self.data.to_csv(cluster_data_path, index=False)

        print("Clustering completado y resultados guardados.")

    def detect_anomalies(self, anomaly_detector=IsolationForest, separator=[','], scalers=None, **kwargs):

        anomalies_folder = os.path.join(self.output_folder, 'anomalies')
        if not os.path.exists(anomalies_folder):
            os.mkdir(anomalies_folder)
        
        # preprocesamiento de datos
        self.clean_data(separator = separator)
        scaled_data = self.scale(scalers=scalers)

        print("Procesamiento de datos completado.")

        # seleccion de columnas numericas
        numeric_columns = scaled_data.select_dtypes(include=['number']).columns

        try:
            detector = anomaly_detector(**kwargs)  # Crear una instancia del detector de anomalías
        except Exception as e:
            raise ValueError(f"No se pudo crear el detector de anomalías: {e}")

        # Entrenar el detector de anomalías
        anomaly_labels = detector.fit_predict(scaled_data[numeric_columns])

        # Aplicar PCA
        pca = PCA(n_components=2)
        data_pca = pca.fit_transform(scaled_data[numeric_columns])

        # Graficar los datos con colores basados en las etiquetas de anomalias
        plt.scatter(data_pca[:, 0], data_pca[:, 1], c=anomaly_labels, cmap='viridis')
        plt.title('Data PCA con Colores de Anomaly Labels')
        plt.xlabel('Dimension 1')
        plt.ylabel('Dimension 2')
        plt.savefig(os.path.join(anomalies_folder, 'anomalies_projection.png'))
        plt.show()
        plt.close()

        self.data['anomalies'] = anomaly_labels

        # Guardar los datos con su respectivo cluster en formato .csv
        anomalies_data_path = os.path.join(anomalies_folder, 'data_anomalies.csv')
        self.data.to_csv(anomalies_data_path, index=False)

        print("Detección de anomalias completado y resultados guardados.")
    
    def profile(self):
        self.summarize()
        self.plot_vars()
        self.clean_data()
        self.scale()
        self.make_clusters()
        self.detect_anomalies()
    
    def clearGarbage(self):

        carpeta_a_limpiar = self.output_folder

       # Eliminar archivos en la carpeta
        archivos_en_carpeta = os.listdir(carpeta_a_limpiar)

        for archivo in archivos_en_carpeta:
            ruta_completa = os.path.join(carpeta_a_limpiar, archivo)
            try:
                if os.path.isfile(ruta_completa):
                    os.remove(ruta_completa)
                    print(f"Archivo eliminado: {ruta_completa}")
                elif os.path.isdir(ruta_completa):
                    shutil.rmtree(ruta_completa)
                    print(f"Carpeta eliminada: {ruta_completa}")
            except Exception as e:
                print(f"No se pudo eliminar {ruta_completa}: {e}")

        print(f"Contenido de la carpeta '{carpeta_a_limpiar}' eliminado exitosamente.")

# %% [markdown]
# ## 1.2 Caracterizar datos de Olimpiadas (2.0 puntos)
#
# A partir de la clase que hemos desarrollado previamente, procederemos a realizar un análisis exhaustivo de los datos proporcionados en el enunciado. Este análisis se presentará en forma de un informe contenido en el mismo Jupyter Notebook y abordará los siguientes puntos:
#
# 1. Introducción
#     - Se proporcionará una breve descripción del problema que estamos abordando y se explicará la metodología que se seguirá.
#
# Elaborar una breve introducción con todo lo necesario para entender qué realizarán durante su proyecto. La idea es que describan de manera formal el proyecto con sus propias palabras y logren describir algunos aspectos básicos tanto del dataset como del análisis a realizar sobre los datos.
#
# Por lo anterior, en esta sección ustedes deberán ser capaces de:
#
# - Describir la tarea asociada al dataset.
# - Describir brevemente los datos de entrada que les provee el problema.
# - Plantear hipótesis de cómo podrían abordar el problema.
#
# 2. Análisis del EDA (Análisis Exploratorio de Datos)
#     - Se discutirán las observaciones y conclusiones obtenidas acerca de los datos proporcionados. A lo largo de su respuesta, debe responder preguntas como:
#         - ¿Como se comportan las variables numéricas? ¿y las categóricas?
#         - ¿Existen valores nulos en el dataset? ¿En qué columnas? ¿Cuantos?
#         - ¿Cuáles son las categorías y frecuencias de las variables categóricas?
#         - ¿Existen datos duplicados en el conjunto?
#         - ¿Existen relaciones o patrones visuales entre las variables?
#         - ¿Existen anomalías notables o preocupantes en los datos?
# 3. Creación de Clusters y Anomalías
#     - Se justificará la elección de los algoritmos a utilizar y sus hiperparámetros. En el caso de clustering, justifique además el número de clusters.
#
# 4. Análisis de Resultados
#     - Se examinarán los resultados obtenidos a partir de los clústers y anomalías generadas. ¿Se logra una separación efectiva de los datos? Entregue una interpretación de lo que representa cada clúster y anomalía.
# 5. Conclusión
#     - Se resumirán las principales conclusiones del análisis y se destacarán las implicaciones prácticas de los resultados obtenidos.

# %% [markdown]
# # Informe de caracterización de datos
#
# ## Introducción
#
# La caracterización de datos es una tarea fundamental para un analista o cientista de datos. En el presente informe se describirá el trabajo realizado en el proyecto de caracterización de datos para los juegos de Santiago 2023, con el fin de caracterizar de forma automática los datos que se recopilarán a futuro. Para ello, se construyó la clase `Profiler` que contiene una serie de métodos útiles para la transformación y descripción de los datos y se utilizó la base de datos `olimpiadas.parquet` como set de prueba de los métodos de `Profiler`. Esta base de datos cuenta con información histórica de deportistas participantes en los juegos olímpicos, tales como su nombre, sexo, equipo, en qué juegos participó, deporte, etc.
#
# Para el trabajo de análisis y exploración de datos, se espera ejecutar una `pipeline` que contenga los pasos de limpieza, para seguir con un análisis descriptivo por cada columna del set de datos, luego se espera hacer análisis estadísticos básicos de las variables numéricas y categóricas a través de gráficos de dispersión e histogramas, respectivamente. Para luego finalizar con la clusterización de los datos, su proyección en dos dimensiones y la detección de posibles anomalías.
#
# ## Análisis del EDA
#
# Primeramente se cargará la base de datos y se mostrarán valores de ejemplo:

# %%
# abrir parquet
df = pd.read_parquet('olimpiadas.parquet')
olimpiadas = Profiler(df)
olimpiadas.data.head()
# Out:
#    ID                      Name Sex            Team  NOC        Games  Year  \
# 0   1                 A Dijiang   M           China  CHN  1992 Summer  1992
# 1   2                  A Lamusi   M           China  CHN  2012 Summer  2012
# 2   3       Gunnar Nielsen Aaby   M         Denmark  DEN  1920 Summer  1920
# 3   4      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN  1900 Summer  1900
# 4   5  Christine Jacoba Aaftink   F     Netherlands  NED  1988 Winter  1988
#
#    Season       City          Sport                             Event Medal  \
# 0  Summer  Barcelona     Basketball       Basketball Men's Basketball  None
# 1  Summer     London           Judo      Judo Men's Extra-Lightweight  None
# 2  Summer  Antwerpen       Football           Football Men's Football  None
# 3  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres  None
#
#   age-height-weight
# 0   24.0*180.0?80.0
# ...

# %% [markdown]
# Se realizará un `Summarize` en todas las columnas como primera aproximación.

# %%
olimpiadas.summarize()
# Out:
# Resumen del Dataset:
# Variable: ID
# Tipo de Variable: int64
# Número de Valores Únicos: 135571 (50.00%)
# Número de Valores Nulos: 0 (0.00%)
# Estadísticas Descriptivas:
# Valor Mínimo: 1
# Percentil 25: 34643.0
# Media: 68248.95439590434
# Percentil 50 (Mediana): 68205.0
# Percentil 75: 102097.25
# Valor Máximo: 135571
# Número de Valores Cero: 0 (0.00%)
# Número de Valores Negativos: 0 (0.00%)
# Número de Outliers: 0 (0.00%)
#
# Variable: Name
# Tipo de Variable: object
# Número de Valores Únicos: 134732 (49.70%)
# Número de Valores Nulos: 0 (0.00%)
#
# Variable: Sex
# Tipo de Variable: object
# Número de Valores Únicos: 2 (0.00%)
# Número de Valores Nulos: 0 (0.00%)
#
# Variable: Team
# Tipo de Variable: object
# Número de Valores Únicos: 1184 (0.44%)
# Número de Valores Nulos: 0 (0.00%)
#
# Variable: NOC
# Tipo de Variable: object
# Número de Valores Únicos: 230 (0.08%)
# Número de Valores Nulos: 0 (0.00%)
#
# Variable: Games
# Tipo de Variable: object
# ...

# %% [markdown]
# El dataset presenta 231333 valores nulos en la columna `Medal`, correspondiente a un 85.33% de los datos de la columna. Estos datos corresponden a la cantidad de atletas que no ganaron medalla durante su participación, por lo que, a priori, no deberían ser eliminados. Podemos notar que existe una gran catidad de datos duplicados en cada columna, lo cual hace sentido pues gran parte de los datos corresponden a información como el sexo del atleta, el tipo de medalla recibida (oro, plata, bronce o ninguna), el deporte que practican, el país de procedencia o los juegos, año y sede donde participaron. Las variables con menor cantidad de datos repetidos fueron las columnas `Name` y `ID`, que presentan alrededor del 50% de los datos duplicados, lo cual es una muestra de que gran cantidad de los atletas participan en más de una competición o bien, en más de un juego olímpico.
#
# Es posible notar que la columna `age-weight-height` tiene separadores en cada una de sus observaciones, por lo que se utilizará `clean_data` para separar las columnas no atómicas

# %%
olimpiadas.clean_data(separator=['*', '?', '(', ':'], columns_of_interest=['age-height-weight'], impute_technique='impute_mean')
olimpiadas.data.head()
# Out:
# Index(['age-height-weight_0', 'age-height-weight_1', 'age-height-weight_2'], dtype='object')
# Hay  1385  datos duplicados
#    ID                      Name Sex            Team  NOC        Games  Year  \
# 0   1                 A Dijiang   M           China  CHN  1992 Summer  1992
# 1   2                  A Lamusi   M           China  CHN  2012 Summer  2012
# 2   3       Gunnar Nielsen Aaby   M         Denmark  DEN  1920 Summer  1920
# 3   4      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN  1900 Summer  1900
# 4   5  Christine Jacoba Aaftink   F     Netherlands  NED  1988 Winter  1988
#
#    Season       City          Sport                             Event Medal  \
# 0  Summer  Barcelona     Basketball       Basketball Men's Basketball  None
# 1  Summer     London           Judo      Judo Men's Extra-Lightweight  None
# 2  Summer  Antwerpen       Football           Football Men's Football  None
# 3  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %% [markdown]
# Se cambiarán los nombres a las nuevas columnas

# %%
# cambiar nombres de columnas

olimpiadas.data.rename(columns={'age-height-weight_0': 'age',
                                'age-height-weight_1': 'height',
                                'age-height-weight_2': 'weight'}, inplace=True)
olimpiadas.data.head()
# Out:
#    ID                      Name Sex            Team  NOC        Games  Year  \
# 0   1                 A Dijiang   M           China  CHN  1992 Summer  1992
# 1   2                  A Lamusi   M           China  CHN  2012 Summer  2012
# 2   3       Gunnar Nielsen Aaby   M         Denmark  DEN  1920 Summer  1920
# 3   4      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN  1900 Summer  1900
# 4   5  Christine Jacoba Aaftink   F     Netherlands  NED  1988 Winter  1988
#
#    Season       City          Sport                             Event Medal  \
# 0  Summer  Barcelona     Basketball       Basketball Men's Basketball  None
# 1  Summer     London           Judo      Judo Men's Extra-Lightweight  None
# 2  Summer  Antwerpen       Football           Football Men's Football  None
# 3  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres  None
#
#     age     height     weight
# ...

# %% [markdown]
# Graficaremos algunas variables que sean de interés
#
# - Variables numéricas

# %%
# age, height y weight son numéricas
olimpiadas.plot_vars(columns_of_interest=['age', 'height', 'weight'])

# %% [markdown]
# Podemos notar que los atletas se encuentran con mayor densidad entre los 20 a 26 años, 170cm a 180cm de altura y 65kg a 75kg aproximadamente. Las tres variables presentan un comportamiento gaussiano. Se logra observar una correlación clara entre altura y peso de los atletas.
#
# - Variables categóricas

# %%
# variables categoricas
olimpiadas.plot_vars(columns_of_interest=['Team', 'Games', 'Sport', 'Event'], top_n_categories=20)

# %%
olimpiadas.make_clusters(algorithm = 'KMeans', scalers=None, separator=None, min_clusters=1, max_clusters=10)
# Out:
# No se especificó un separador. No se realizará la separación de columnas.
# Hay  0  datos duplicados
# Procesamiento de datos completado.
# C:\Users\diego\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\diego\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...
